# %%
#靜態 2D 3D plot: matplotlib
#互動式2D plotly, Cufflinks, Dash

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
np.random.seed(seed=123456)
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))
ts = ts.cumsum()

df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list("ABCD"))
df = df.cumsum()

ts.plot()
df.plot()
# Out:
# <AxesSubplot:>

# %%
#指定 x y

df2 = pd.DataFrame(np.random.randn(1000, 2), columns=["B", "C"]).cumsum()
df2['A'] = pd.Series(list(range(len(df2))))
df2.plot(x='A', y='B')
# Out:
# <AxesSubplot:xlabel='A'>

# %%
#line style

t = np.arange(0., 5., 0.2)
legend_labels = ['Solid', 'Dashed', 'Dotted', 
                 'Dot-dashed', 'Points']
df3 = pd.DataFrame({0 : t,
                           1 : t**1.5,
                           2 : t**2.0,
                           3 : t**2.5,
                           4 : t**3.0})
ax = df3.plot(style=['r-', 'g--', 'b:', 'm-.', 'k:'])
ax.legend(legend_labels, loc='upper left')

# %%
df4 = pd.DataFrame(np.arange(0,5))
plt.plot(df4)
plt.xticks(np.arange(-2, 6))
plt.yticks(np.arange(0, 5), list("ABCDE"))
# Out:
# ([<matplotlib.axis.YTick at 0x7fe7fe37e8b0>,
# ...
#  [Text(0, 0, 'A'),
#   Text(0, 1, 'B'),
#   Text(0, 2, 'C'),
#   Text(0, 3, 'D'),
#   Text(0, 4, 'E')])

# %%
df5 = pd.DataFrame(np.random.randn(1000, 4), columns=list("ABCD"))
df5 = df.cumsum()
df5.iloc[5]
df5.iloc[5].plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df6 = pd.DataFrame(np.random.rand(10, 4), columns=["a", "b", "c", "d"])
df6.plot.bar()
df6.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
df7 = pd.DataFrame({"a": np.random.randn(1000) + 1,"b": np.random.randn(1000),"c": np.random.randn(1000) - 1,},columns=["a", "b", "c"])
df7.plot.hist(alpha=0.5)
df7.plot.hist(stacked=False, bins=20)
df7.plot.hist(stacked=True, bins=20)
df7.plot.hist(stacked=True, bins=50)
df7.plot.hist(stacked=True, bins=50,cumulative=True)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df8 = pd.DataFrame({"a": np.random.randn(1000) + 1,"b": np.random.randn(1000),"c": np.random.randn(1000) - 1,},columns=["a", "b", "c"])
df8.hist(color="k", alpha=0.5, bins=50)
# Out:
# array([[<AxesSubplot:title={'center':'a'}>,
#         <AxesSubplot:title={'center':'b'}>],
#        [<AxesSubplot:title={'center':'c'}>, <AxesSubplot:>]], dtype=object)

# %%
df9 = pd.DataFrame(np.random.rand(10, 5), columns=["A", "B", "C", "D", "E"])
df9.plot.box()
# Out:
# <AxesSubplot:>

# %%
df10 = pd.DataFrame(np.random.rand(10, 2), columns=["Col1", "Col2"])
df10["X"] = pd.Series(["A", "A", "A", "A", "A", "B", "B", "B", "B", "B"])
df10.boxplot(by="X")
# Out:
# array([<AxesSubplot:title={'center':'Col1'}, xlabel='[X]'>,
#        <AxesSubplot:title={'center':'Col2'}, xlabel='[X]'>], dtype=object)

# %%
df11 = pd.DataFrame(np.random.rand(10, 4), columns=["a", "b", "c", "d"])
df11.plot.area(ylim=(0,3))
df11.plot.area(stacked=False,ylim=(0,3))
# Out:
# <AxesSubplot:>

# %%
df12 = pd.DataFrame(np.random.rand(50, 4), columns=["a", "b", "c", "d"])
df12.plot.scatter(x="a", y="b")
#c(color), s(size)
df12.plot.scatter(x="a", y="b", c='d', s=df12['c']*100)
df12.plot.scatter(x="a", y="b", c='d', cmap='coolwarm')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df13 = pd.DataFrame(np.random.randn(1000, 2), columns=["a", "b"])
df13["b"] = df13["b"] + np.arange(1000)
df13.plot.hexbin(x="a", y="b", gridsize=25)
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
from pandas.plotting import scatter_matrix
df14 = pd.DataFrame(np.random.randn(1000, 4), columns=["a", "b", "c", "d"])
df14.d = df.d-1
#注意d
scatter_matrix(df14, alpha=0.2, figsize=(6, 6), diagonal="kde")
# Out:
# array([[<AxesSubplot:xlabel='a', ylabel='a'>,
#         <AxesSubplot:xlabel='b', ylabel='a'>,
#         <AxesSubplot:xlabel='c', ylabel='a'>,
#         <AxesSubplot:xlabel='d', ylabel='a'>],
#        [<AxesSubplot:xlabel='a', ylabel='b'>,
#         <AxesSubplot:xlabel='b', ylabel='b'>,
#         <AxesSubplot:xlabel='c', ylabel='b'>,
#         <AxesSubplot:xlabel='d', ylabel='b'>],
#        [<AxesSubplot:xlabel='a', ylabel='c'>,
#         <AxesSubplot:xlabel='b', ylabel='c'>,
#         <AxesSubplot:xlabel='c', ylabel='c'>,
#         <AxesSubplot:xlabel='d', ylabel='c'>],
#        [<AxesSubplot:xlabel='a', ylabel='d'>,
#         <AxesSubplot:xlabel='b', ylabel='d'>,
#         <AxesSubplot:xlabel='c', ylabel='d'>,
#         <AxesSubplot:xlabel='d', ylabel='d'>]], dtype=object)

# %%
# Density plot
# 這個圖的數值方法詳見官方doc
df15 = pd.Series(np.random.randn(1000))
df15.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
# Multiple Plots in a Single Chart
ax1 = plt.subplot2grid(shape=(2,1), loc=(0,0))
ax2 = plt.subplot2grid(shape=(2,1), loc=(1,0))

# %%
ax1 = plt.subplot2grid((4,4), (0,0), colspan=4)
ax2 = plt.subplot2grid((4,4), (1,0), colspan=2)
ax3 = plt.subplot2grid((4,4), (1,2), colspan=2, rowspan=2)
ax4 = plt.subplot2grid((4,4), (2,0))
ax5 = plt.subplot2grid((4,4), (2,1))

# %%
from matplotlib.dates import WeekdayLocator, DateFormatter, MonthLocator

s = pd.Series(np.random.randn(1096),index=pd.date_range('2012-01-01', '2014-12-31'))
walk_ts = s.cumsum()
walk_df = pd.DataFrame(walk_ts)

# plot Jan-Feb 2014
ax = walk_df.loc['2014-01':'2014-02'].plot()

# do the minor labels
weekday_locator = WeekdayLocator(byweekday=(0), interval=1)
ax.xaxis.set_minor_locator(weekday_locator)
ax.xaxis.set_minor_formatter(DateFormatter("%d\n%a"))

# do the major labels
ax.xaxis.set_major_locator(MonthLocator())
ax.xaxis.set_major_formatter(DateFormatter('\n\n\n%b\n%Y'))

ax.xaxis.grid(True, "minor") # turn on minor tick grid lines
ax.xaxis.grid(False, "major") # turn off major tick grid lines

# %%
ax6 = plt.subplot2grid((2,1), (0,0))
ax7 = plt.subplot2grid((2,1), (1,0))
walk_df[walk_df.columns[0]].plot(ax = ax6)
walk_df[walk_df.columns[0]].plot(ax = ax7)
# Out:
# <AxesSubplot:>

# %%
msft = pd.read_csv("data/msft.csv")
msft = pd.DataFrame(msft)
msft.Date = pd.to_datetime(msft.Date)
msft.set_index('Date', inplace = True)
msft
# Out:
#              Open   High    Low  Close   Volume
# Date
# 2014-07-21  83.46  83.53  81.81  81.93  2359300
# 2014-07-18  83.30  83.40  82.52  83.35  4020800
# 2014-07-17  84.35  84.63  83.33  83.63  1974000
# 2014-07-16  83.77  84.91  83.66  84.91  1755600
# 2014-07-15  84.30  84.38  83.20  83.58  1874700
# ...           ...    ...    ...    ...      ...
# 2000-01-07  48.55  50.35  47.80  50.00  4621200
# 2000-01-06  46.78  48.35  46.28  48.03  3306100
# 2000-01-05  46.94  47.50  45.92  46.75  4809900
# 2000-01-04  49.80  49.80  47.72  47.85  4489500
# 2000-01-03  52.70  53.20  49.60  49.75  3137300
#
# [3767 rows x 5 columns]

# %%
top = plt.subplot2grid((4,4), (0, 0), rowspan=3, colspan=4)
top.plot(msft.index, msft.Close)

bottom = plt.subplot2grid((4,4), (3,0), rowspan=1, colspan=4)
bottom.bar(msft.index, msft.Volume)

plt.gcf().set_size_inches(15,8)

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list("ABCD"))

fig, axes = plt.subplots(nrows=2, ncols=3)
plt.subplots_adjust(wspace=0.2, hspace=0.5)

df["A"].plot(ax=axes[0, 0])
axes[0, 0].set_title("A")
df["B"].plot(ax=axes[0, 1])
axes[0, 1].set_title("B")
df["C"].plot(ax=axes[1, 2])
axes[1, 2].set_title("C")
df["D"].plot(ax=axes[1, 1])
axes[1, 1].set_title("D")
# Out:
# Text(0.5, 1.0, 'D')

# %%
data = pd.read_csv('data/tr_eikon_eod_data.csv',index_col=0, parse_dates=True)
data.plot(figsize=(10, 12), subplots=False)
data.plot(figsize=(10, 12), subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000272FE41F608>,
# ...
#       dtype=object)

# %%
data2 = pd.read_csv('data/tr_eikon_eod_data.csv',index_col=0, parse_dates=True)
#變動率 (x2 - x1) / x1
data2.pct_change().mean().plot.bar()

# %%
data3 = pd.read_csv('data/tr_eikon_eod_data.csv',index_col=0, parse_dates=True)
#對數報酬率(優點:cumsum計算很方便)
#取log
rets = np.log(data3 / data3.shift(1))
#cumsum(計算方便)
retsCumsum = rets.cumsum()
#反log
retsCumsum.apply(np.exp).plot(figsize=(15, 10), subplots=False)

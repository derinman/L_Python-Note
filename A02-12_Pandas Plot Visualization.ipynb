# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
np.random.seed(seed=123456)
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))
ts = ts.cumsum()
ts
# Out:
# 2000-01-01     0.469112
# 2000-01-02     0.186249
# 2000-01-03    -1.322810
# 2000-01-04    -2.458442
# 2000-01-05    -1.246330
#                 ...
# 2002-09-22   -45.579481
# 2002-09-23   -44.645728
# 2002-09-24   -44.953742
# 2002-09-25   -45.033657
# 2002-09-26   -46.044246
# Freq: D, Length: 1000, dtype: float64

# %%
ts.plot()

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list("ABCD"))
df = df.cumsum()
df
# Out:
#                     A         B         C          D
# 2000-01-01  -0.218470 -0.061645 -0.723780   0.551225
# 2000-01-02  -0.716236  0.775873  0.379465  -0.567160
# 2000-01-03  -1.259217 -0.218128  1.888207  -0.895857
# 2000-01-04  -1.821452 -0.216532  1.965752   0.093877
# 2000-01-05  -3.514107  0.257420  1.276571   0.692263
# ...               ...       ...       ...        ...
# 2002-09-22 -18.386466  2.243464  2.938592  40.416305
# 2002-09-23 -18.601660  2.473306  2.507465  40.119526
# 2002-09-24 -18.440294  0.302185  2.015355  39.135322
# 2002-09-25 -19.177552 -0.810066  3.468941  40.769274
# 2002-09-26 -19.411661  0.004433  3.718648  39.351233
#
# [1000 rows x 4 columns]

# %%
df.plot()

# %%
df3 = pd.DataFrame(np.random.randn(1000, 2), columns=["B", "C"]).cumsum()
df3["A"] = pd.Series(list(range(len(df))))
df3
# Out:
#              B         C    A
# 0     0.879831  0.573687    0
# 1     0.145896  0.149091    1
# 2     1.782761  1.397438    2
# 3    -0.038807  2.758431    3
# 4     0.232905  2.468640    4
# ..         ...       ...  ...
# 995 -27.673706 -3.591743  995
# 996 -29.459943 -3.306978  996
# 997 -27.398674 -2.735528  997
# 998 -29.589450 -2.312671  998
# 999 -29.733052 -3.633835  999
#
# [1000 rows x 3 columns]

# %%
df3.plot(x="A", y="B")

# %%
df.iloc[5]
# Out:
# A   -3.689192
# B    1.297722
# C    2.265614
# D    2.318966
# Name: 2000-01-06 00:00:00, dtype: float64

# %%
df.iloc[5].plot(kind="bar")

# %%
df2 = pd.DataFrame(np.random.rand(10, 4), columns=["a", "b", "c", "d"])
df2.plot.bar()

# %%
df2.plot.bar()

# %%
df2.plot.bar(stacked=True)

# %%
df4 = pd.DataFrame({"a": np.random.randn(1000) + 1,"b": np.random.randn(1000),"c": np.random.randn(1000) - 1,},columns=["a", "b", "c"])
df4
# Out:
#             a         b         c
# 0    1.717808  1.600283 -0.854723
# 1    0.099041 -0.605731 -0.691854
# 2    2.180217 -0.561047 -2.043530
# 3   -0.297617  0.387419 -1.708145
# 4    0.868325 -0.837884  0.430905
# ..        ...       ...       ...
# 995 -0.869881  1.618922 -2.062384
# 996 -1.079393 -1.424723 -0.181155
# 997 -0.471215 -0.023232 -0.975853
# 998  1.426664  0.948196  0.441112
# 999  1.119476  0.183573 -1.661444
#
# [1000 rows x 3 columns]

# %%
df4.plot.hist(alpha=0.5)

# %%
 df4.plot.hist(stacked=True, bins=20)

# %%
 df4.plot.hist(stacked=True, bins=50)

# %%
df4.plot.hist(stacked=True, bins=50,cumulative=True)

# %%
df4.hist(color="k", alpha=0.5, bins=50);

# %%
df = pd.DataFrame(np.random.rand(10, 5), columns=["A", "B", "C", "D", "E"])
df
# Out:
#           A         B         C         D         E
# 0  0.008679  0.882071  0.561102  0.489744  0.246775
# 1  0.443818  0.368385  0.578386  0.517918  0.530062
# 2  0.089721  0.652950  0.223120  0.323104  0.652966
# 3  0.961196  0.632057  0.461773  0.182153  0.742038
# 4  0.669889  0.042705  0.823928  0.711056  0.221865
# 5  0.661446  0.550097  0.715426  0.768972  0.269653
# 6  0.367558  0.642530  0.254340  0.345057  0.101509
# 7  0.879606  0.984164  0.141143  0.432911  0.222028
# 8  0.044788  0.585164  0.054916  0.979542  0.339155
# 9  0.631335  0.419676  0.131963  0.495837  0.469052

# %%
df.plot.box()

# %%
df = pd.DataFrame(np.random.rand(10, 2), columns=["Col1", "Col2"])
df["X"] = pd.Series(["A", "A", "A", "A", "A", "B", "B", "B", "B", "B"])
df
# Out:
#        Col1      Col2  X
# 0  0.852328  0.082633  A
# 1  0.429911  0.307083  A
# 2  0.496940  0.157990  A
# 3  0.357675  0.031861  A
# 4  0.651733  0.015240  A
# 5  0.729848  0.074296  B
# 6  0.394012  0.567838  B
# 7  0.615290  0.482565  B
# 8  0.969125  0.403147  B
# 9  0.431166  0.383294  B

# %%
df.boxplot(by="X")
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000021C66DA2DC8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000021C67E1FC48>],
#       dtype=object)

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=["a", "b", "c", "d"])
df
# Out:
#           a         b         c         d
# 0  0.313496  0.206911  0.159187  0.899476
# 1  0.070719  0.156817  0.145550  0.796451
# 2  0.389773  0.125612  0.802487  0.986458
# 3  0.387455  0.040778  0.364885  0.593510
# 4  0.815579  0.052020  0.394250  0.791686
# 5  0.969851  0.138930  0.610761  0.712440
# 6  0.415231  0.582194  0.230858  0.969582
# 7  0.777244  0.435377  0.675082  0.270338
# 8  0.555685  0.345963  0.947802  0.024445
# 9  0.873230  0.579551  0.166529  0.649804

# %%
df.plot.area()

# %%
df.plot.area(stacked=False)

# %%
df = pd.DataFrame(np.random.rand(50, 4), columns=["a", "b", "c", "d"])
df.plot.scatter(x="a", y="b")

# %%
df.plot.scatter(x="a", y="b", c='d', s=df['c']*100)

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=["a", "b"])
df["b"] = df["b"] + np.arange(1000)
df
# Out:
#             a           b
# 0   -0.364831   -0.348520
# 1    0.202856    1.777088
# 2   -0.358316    1.346852
# 3    0.586314    3.071028
# 4    1.426308    2.480610
# ..        ...         ...
# 995 -1.288864  995.287789
# 996  0.259732  997.001529
# 997  1.495983  997.527018
# 998 -0.079513  996.472216
# 999  0.833964  998.950999
#
# [1000 rows x 2 columns]

# %%
df.plot.hexbin(x="a", y="b", gridsize=25)

# %%
from pandas.plotting import scatter_matrix
df = pd.DataFrame(np.random.randn(1000, 4), columns=["a", "b", "c", "d"])
df
# Out:
#             a         b         c         d
# 0    3.248699  0.870291  0.008549 -0.351076
# 1    1.778667 -0.171559 -1.626753 -1.603976
# 2    0.331643  0.362569  1.582530 -0.013067
# 3    0.364832 -0.106194  1.138642  1.238433
# 4    2.057923 -0.017892 -1.206402  0.491659
# ..        ...       ...       ...       ...
# 995 -2.280252  0.659774  0.017071 -0.022839
# 996 -0.992850 -0.613623 -1.245488  0.164531
# 997 -1.131791  2.095740  0.233819 -0.160260
# 998  1.123495  1.192451 -0.870590 -0.578255
# 999 -0.312175  1.474692  1.413875 -1.874796
#
# [1000 rows x 4 columns]

# %%
scatter_matrix(df, alpha=0.2, figsize=(6, 6), diagonal="kde")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000021C6C479A48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021C6C4D3588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021C6C509188>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021C6C53D648>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000021C6C4C2288>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021C6C58AB48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021C6C5C0EC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021C6C5FA6C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000021C6C6081C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021C6C63AE48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021C6C6A2A48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021C6C6DB648>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000021C6C713608>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021C6C74B748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021C6C783848>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021C6C7BC908>]],
#       dtype=object)

# %%
# Density plot
ser = pd.Series(np.random.randn(1000))
ser.plot.kde()

# %%
import numpy as np
import pandas as pd
from pylab import mpl, plt
plt.style.use('seaborn')
mpl.rcParams['font.family'] = 'serif'

# %%
data1 = pd.read_csv('data/tr_eikon_eod_data.csv',index_col=0, parse_dates=True)
data1.head()
# Out:
#                AAPL.O  MSFT.O  INTC.O  AMZN.O    GS.N     SPY     .SPX   .VIX  \
# Date
# 2010-01-01        NaN     NaN     NaN     NaN     NaN     NaN      NaN    NaN
# 2010-01-04  30.572827  30.950   20.88  133.90  173.08  113.33  1132.99  20.04
# 2010-01-05  30.625684  30.960   20.87  134.69  176.14  113.63  1136.52  19.35
# 2010-01-06  30.138541  30.770   20.80  132.25  174.26  113.71  1137.14  19.16
# 2010-01-07  30.082827  30.452   20.60  130.00  177.67  114.19  1141.69  19.06
#
#               EUR=     XAU=    GDX     GLD
# Date
# 2010-01-01  1.4323  1096.35    NaN     NaN
# 2010-01-04  1.4411  1120.00  47.71  109.80
# 2010-01-05  1.4368  1118.65  48.17  109.70
# 2010-01-06  1.4412  1138.50  49.34  111.51
# 2010-01-07  1.4318  1131.90  49.10  110.82

# %%
data2 = pd.read_csv('data/tr_eikon_eod_data.csv',index_col=0, parse_dates=True)
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2216 entries, 2010-01-01 to 2018-06-29
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL.O  2138 non-null   float64
#  1   MSFT.O  2138 non-null   float64
#  2   INTC.O  2138 non-null   float64
#  3   AMZN.O  2138 non-null   float64
#  4   GS.N    2138 non-null   float64
#  5   SPY     2138 non-null   float64
#  6   .SPX    2138 non-null   float64
#  7   .VIX    2138 non-null   float64
#  8   EUR=    2216 non-null   float64
#  9   XAU=    2211 non-null   float64
#  10  GDX     2138 non-null   float64
#  11  GLD     2138 non-null   float64
# dtypes: float64(12)
# memory usage: 225.1 KB

# %%
data3 = pd.read_csv('data/tr_eikon_eod_data.csv',index_col=0, parse_dates=True)
data3.describe().round(3)
# Out:
#          AAPL.O    MSFT.O    INTC.O    AMZN.O      GS.N       SPY      .SPX  \
# count  2138.000  2138.000  2138.000  2138.000  2138.000  2138.000  2138.000
# mean     93.456    44.561    29.364   480.461   170.216   180.323  1802.713
# std      40.552    19.528     8.172   372.308    42.484    48.190   483.337
# min      27.436    23.010    17.665   108.610    87.700   102.200  1022.580
# 25%      60.294    28.567    22.510   213.595   146.608   133.987  1338.567
# 50%      90.551    39.660    27.330   322.065   164.430   186.320  1863.080
# 75%     117.235    54.372    34.710   698.850   192.132   210.988  2108.942
# max     193.980   102.490    57.080  1750.080   273.380   286.580  2872.870
#
#            .VIX      EUR=      XAU=       GDX       GLD
# count  2138.000  2216.000  2211.000  2138.000  2138.000
# mean     17.027     1.249  1349.014    33.567   130.087
# std       5.883     0.114   188.746    15.170    18.784
# min       9.140     1.038  1051.360    12.470   100.500
# ...

# %%
data4 = pd.read_csv('data/tr_eikon_eod_data.csv',index_col=0, parse_dates=True)
data4.plot(figsize=(20, 12), subplots=False)
data4.plot(figsize=(20, 12), subplots=True)
# Out:
# array([<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>],
#       dtype=object)

# %%
data5 = pd.read_csv('data/tr_eikon_eod_data.csv',index_col=0, parse_dates=True)
data5.aggregate([min,  
                np.mean,  
                np.std,  
                np.median,  
                max]  
).round(2)
# Out:
#         AAPL.O  MSFT.O  INTC.O   AMZN.O    GS.N     SPY     .SPX   .VIX  EUR=  \
# min      27.44   23.01   17.66   108.61   87.70  102.20  1022.58   9.14  1.04
# mean     93.46   44.56   29.36   480.46  170.22  180.32  1802.71  17.03  1.25
# std      40.55   19.53    8.17   372.31   42.48   48.19   483.34   5.88  0.11
# median   90.55   39.66   27.33   322.06  164.43  186.32  1863.08  15.58  1.27
# max     193.98  102.49   57.08  1750.08  273.38  286.58  2872.87  48.00  1.48
#
#            XAU=    GDX     GLD
# min     1051.36  12.47  100.50
# mean    1349.01  33.57  130.09
# std      188.75  15.17   18.78
# median  1292.61  25.62  124.00
# max     1898.99  66.63  184.59

# %%
data6 = pd.read_csv('data/tr_eikon_eod_data.csv',index_col=0, parse_dates=True)
data6.diff().head()
# Out:
#               AAPL.O  MSFT.O  INTC.O  AMZN.O  GS.N   SPY  .SPX  .VIX    EUR=  \
# Date
# 2010-01-01       NaN     NaN     NaN     NaN   NaN   NaN   NaN   NaN     NaN
# 2010-01-04       NaN     NaN     NaN     NaN   NaN   NaN   NaN   NaN  0.0088
# 2010-01-05  0.052857   0.010   -0.01    0.79  3.06  0.30  3.53 -0.69 -0.0043
# 2010-01-06 -0.487142  -0.190   -0.07   -2.44 -1.88  0.08  0.62 -0.19  0.0044
# 2010-01-07 -0.055714  -0.318   -0.20   -2.25  3.41  0.48  4.55 -0.10 -0.0094
#
#              XAU=   GDX   GLD
# Date
# 2010-01-01    NaN   NaN   NaN
# 2010-01-04  23.65   NaN   NaN
# 2010-01-05  -1.35  0.46 -0.10
# 2010-01-06  19.85  1.17  1.81
# 2010-01-07  -6.60 -0.24 -0.69

# %%
data7 = pd.read_csv('data/tr_eikon_eod_data.csv',index_col=0, parse_dates=True)
# 變化率
data7.pct_change().round(3).head()
# Out:
#             AAPL.O  MSFT.O  INTC.O  AMZN.O   GS.N    SPY   .SPX   .VIX   EUR=  \
# Date
# 2010-01-01     NaN     NaN     NaN     NaN    NaN    NaN    NaN    NaN    NaN
# 2010-01-04     NaN     NaN     NaN     NaN    NaN    NaN    NaN    NaN  0.006
# 2010-01-05   0.002   0.000  -0.000   0.006  0.018  0.003  0.003 -0.034 -0.003
# 2010-01-06  -0.016  -0.006  -0.003  -0.018 -0.011  0.001  0.001 -0.010  0.003
# 2010-01-07  -0.002  -0.010  -0.010  -0.017  0.020  0.004  0.004 -0.005 -0.007
#
#              XAU=    GDX    GLD
# Date
# 2010-01-01    NaN    NaN    NaN
# 2010-01-04  0.022    NaN    NaN
# 2010-01-05 -0.001  0.010 -0.001
# 2010-01-06  0.018  0.024  0.016
# 2010-01-07 -0.006 -0.005 -0.006

# %%
data8 = pd.read_csv('data/tr_eikon_eod_data.csv',index_col=0, parse_dates=True)
data8.pct_change().mean().plot(kind='bar', figsize=(10, 6))
# Out:
# <AxesSubplot:>

# %%
data9 = pd.read_csv('data/tr_eikon_eod_data.csv',index_col=0, parse_dates=True)
#取log, 方便計算(cumsum)
data9 = np.log(data9 / data9.shift(1))
data9 = data9.cumsum()
#取指數
data9.apply(np.exp)
# Out:
#               AAPL.O    MSFT.O    INTC.O     AMZN.O      GS.N       SPY  \
# Date
# 2010-01-01       NaN       NaN       NaN        NaN       NaN       NaN
# 2010-01-04       NaN       NaN       NaN        NaN       NaN       NaN
# 2010-01-05  1.001729  1.000323  0.999521   1.005900  1.017680  1.002647
# 2010-01-06  0.985795  0.994184  0.996169   0.987677  1.006818  1.003353
# 2010-01-07  0.983973  0.983910  0.986590   0.970874  1.026520  1.007588
# ...              ...       ...       ...        ...       ...       ...
# 2018-06-25  4.335277  2.769806  2.248841  10.277192  1.268676  2.213622
# 2018-06-26  4.389061  2.789231  2.202720  10.449843  1.268905  2.218523
# 2018-06-27  4.382635  2.745878  2.162364  10.260879  1.260888  2.200145
# 2018-06-28  4.414525  2.776563  2.184094  10.513862  1.279442  2.212724
# 2018-06-29  4.405243  2.776000  2.204493  10.503666  1.263121  2.215910
#
#                 .SPX      .VIX      EUR=      XAU=       GDX       GLD
# Date
# ...

# %%
#可與 data25 比較
data10 = pd.read_csv('data/tr_eikon_eod_data.csv',index_col=0, parse_dates=True)

data10 = np.log(data10 / data10.shift(1)).cumsum().apply(np.exp)
data10.plot(figsize=(10, 6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
data11 = pd.read_csv('data/tr_eikon_eod_data.csv',index_col=0, parse_dates=True)
#resample by week
data11.resample('1w', label='right').last().head()
# Out:
#                AAPL.O  MSFT.O  INTC.O  AMZN.O    GS.N     SPY     .SPX   .VIX  \
# Date
# 2010-01-03        NaN     NaN     NaN     NaN     NaN     NaN      NaN    NaN
# 2010-01-10  30.282827   30.66   20.83  133.52  174.31  114.57  1144.98  18.13
# 2010-01-17  29.418542   30.86   20.80  127.14  165.21  113.64  1136.03  17.91
# 2010-01-24  28.249972   28.96   19.91  121.43  154.12  109.21  1091.76  27.31
# 2010-01-31  27.437544   28.18   19.40  125.41  148.72  107.39  1073.87  24.62
#
#               EUR=     XAU=    GDX     GLD
# Date
# 2010-01-03  1.4323  1096.35    NaN     NaN
# 2010-01-10  1.4412  1136.10  49.84  111.37
# 2010-01-17  1.4382  1129.90  47.42  110.86
# 2010-01-24  1.4137  1092.60  43.79  107.17
# 2010-01-31  1.3862  1081.05  40.72  105.96

# %%
data12 = pd.read_csv('data/tr_eikon_eod_data.csv',index_col=0, parse_dates=True)
data12['AAPL.O']
# Out:
# Date
# 2010-01-01           NaN
# 2010-01-04     30.572827
# 2010-01-05     30.625684
# 2010-01-06     30.138541
# 2010-01-07     30.082827
#                  ...
# 2018-06-25    182.170000
# 2018-06-26    184.430000
# 2018-06-27    184.160000
# 2018-06-28    185.500000
# 2018-06-29    185.110000
# Name: AAPL.O, Length: 2216, dtype: float64

# %%
data13 = pd.read_csv('data/tr_eikon_eod_data.csv',index_col=0, parse_dates=True)
pd.DataFrame(data13['AAPL.O']).dropna()
# Out:
#                 AAPL.O
# Date
# 2010-01-04   30.572827
# 2010-01-05   30.625684
# 2010-01-06   30.138541
# 2010-01-07   30.082827
# 2010-01-08   30.282827
# ...                ...
# 2018-06-25  182.170000
# 2018-06-26  184.430000
# 2018-06-27  184.160000
# 2018-06-28  185.500000
# 2018-06-29  185.110000
#
# [2138 rows x 1 columns]

# %%
data14 = pd.read_csv('data/tr_eikon_eod_data.csv',index_col=0, parse_dates=True)
window = 20
code = 'AAPL.O'
data14 = pd.DataFrame(data14[code])
data14['{}_min'.format(window)] = data14[code].rolling(window=window).min()
data14['{}_max'.format(window)] = data14[code].rolling(window=window).max()
data14['{}_median'.format(window)] = data14[code].rolling(window=window).median()
data14['{}_mean'.format(window)] = data14[code].rolling(window=window).mean()
data14['{}_ewma'.format(window)] = data14[code].ewm(halflife=0.5, min_periods=window).mean()
data14.dropna()
# Out:
#                 AAPL.O      20_min      20_max   20_median     20_mean  \
# Date
# 2010-03-15   31.977111   28.151258   32.371396   29.845684   30.107177
# 2010-03-16   32.064254   28.151258   32.371396   29.879970   30.257534
# 2010-03-17   32.017111   28.151258   32.371396   30.002827   30.411605
# 2010-03-18   32.092825   28.151258   32.371396   30.689969   30.566762
# 2010-03-19   31.749954   28.151258   32.371396   31.287826   30.713761
# ...                ...         ...         ...         ...         ...
# 2018-06-25  182.170000  182.170000  193.980000  189.540000  189.206000
# 2018-06-26  184.430000  182.170000  193.980000  189.540000  189.032500
# 2018-06-27  184.160000  182.170000  193.980000  189.540000  188.865500
# 2018-06-28  185.500000  182.170000  193.980000  189.540000  188.797000
# 2018-06-29  185.110000  182.170000  193.980000  188.790000  188.540500
#
#                20_ewma
# Date
# 2010-03-15   32.062742
# 2010-03-16   32.063876
# 2010-03-17   32.028802
# ...

# %%
data15 = pd.read_csv('data/tr_eikon_eod_data.csv',index_col=0, parse_dates=True)
window = 20
code = 'AAPL.O'

#dropna要先再三確認
data15 = pd.DataFrame(data15[code]).dropna()
data15['{}_min'.format(window)] = data15[code].rolling(window=window).min()
data15['{}_max'.format(window)] = data15[code].rolling(window=window).max()
data15['{}_median'.format(window)] = data15[code].rolling(window=window).median()
data15['{}_mean'.format(window)] = data15[code].rolling(window=window).mean()
#請看A02-06_Pandas Statistics Rolling.ipynb
data15['{}_ewma'.format('30half')] = data15[code].ewm(halflife=30, min_periods=60).mean()
data15['{}_ewma'.format('60half')] = data15[code].ewm(halflife=60, min_periods=120).mean()


ax = data15[[   '{}_min'.format(window),
                '{}_mean'.format(window),
                '{}_max'.format(window), 
                '{}_ewma'.format('30half'),
                '{}_ewma'.format('60half')]
            ].iloc[-200:].plot(figsize=(20, 14), style=['g--', 'r--', 'g--','y--','b--'], lw=0.8)  
data15[code].iloc[-200:].plot(ax=ax, lw=3.0)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#simple moving average(SMA)
data16 = pd.read_csv('data/tr_eikon_eod_data.csv',index_col=0, parse_dates=True)

code = 'AAPL.O'
data16 = pd.DataFrame(data16[code]).dropna()
data16['SMA0'] = data16[code].rolling(window=21).mean()
data16['SMA1'] = data16[code].rolling(window=42).mean()
data16['SMA2'] = data16[code].rolling(window=252).mean()
data16['SMA3'] = data16[code].rolling(window=365).mean()
data16[[code,'SMA0', 'SMA1', 'SMA2','SMA3']].plot(figsize=(20, 12))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#simple moving average(SMA)
data17 = pd.read_csv('data/tr_eikon_eod_data.csv',index_col=0, parse_dates=True)

code = 'AAPL.O'
data17 = pd.DataFrame(data17[code]).dropna()
data17['SMA1'] = data17[code].rolling(window=42).mean()
data17['SMA2'] = data17[code].rolling(window=252).mean()
data17['positions'] = np.where(data17['SMA1'] > data17['SMA2'],  1,  -1)  
 
ax = data17[[code, 'SMA1', 'SMA2', 'positions']].plot(figsize=(20, 12),secondary_y='positions')
ax.get_legend().set_bbox_to_anchor((0.12, 0.9))

# %%
data18 = pd.read_csv('data/tr_eikon_eod_data.csv', index_col=0, parse_dates=True)
data18 = data18[['.SPX', '.VIX']].dropna()
data18
# Out:
#                .SPX   .VIX
# Date
# 2010-01-04  1132.99  20.04
# 2010-01-05  1136.52  19.35
# 2010-01-06  1137.14  19.16
# 2010-01-07  1141.69  19.06
# 2010-01-08  1144.98  18.13
# ...             ...    ...
# 2018-06-25  2717.07  17.33
# 2018-06-26  2723.06  15.92
# 2018-06-27  2699.63  17.91
# 2018-06-28  2716.31  16.85
# 2018-06-29  2718.37  16.09
#
# [2138 rows x 2 columns]

# %%
from scipy import stats

data19 = pd.read_csv('data/tr_eikon_eod_data.csv', index_col=0, parse_dates=True)
data19 = data19[['.SPX', '.VIX']].dropna()
data19['.SPX_Z'] = stats.zscore(data19['.SPX'])
data19['.VIX_Z'] = stats.zscore(data19['.VIX'])

data19.plot(subplots=True, figsize=(10,6))
data19[['.SPX','.VIX']].plot(secondary_y='.VIX', figsize=(10, 6))
data19[['.SPX_Z','.VIX_Z']].plot(secondary_y='.VIX', figsize=(10, 6))
data19.loc[:'2012-12-31'][['.SPX','.VIX']].plot(secondary_y='.VIX', figsize=(10, 6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
data20 = pd.read_csv('data/tr_eikon_eod_data.csv', index_col=0, parse_dates=True)
data20 = data19[['.SPX', '.VIX']].dropna()

pd.plotting.scatter_matrix(data20, alpha=0.2, diagonal='hist', hist_kwds={'bins': 35}, figsize=(10, 6))
# Out:
# array([[<AxesSubplot:xlabel='.SPX', ylabel='.SPX'>,
#         <AxesSubplot:xlabel='.VIX', ylabel='.SPX'>],
#        [<AxesSubplot:xlabel='.SPX', ylabel='.VIX'>,
#         <AxesSubplot:xlabel='.VIX', ylabel='.VIX'>]], dtype=object)

# %%
data21 = pd.read_csv('data/tr_eikon_eod_data.csv', index_col=0, parse_dates=True)
data21 = data21[['.SPX', '.VIX']].dropna()

data21 = (data21 / data21.shift(1)).dropna()
pd.plotting.scatter_matrix(data21, alpha=0.2, diagonal='hist', hist_kwds={'bins': 35}, figsize=(10, 6))

data21 = np.log(data21 / data21.shift(1)).dropna()
pd.plotting.scatter_matrix(data21, alpha=0.2, diagonal='hist', hist_kwds={'bins': 35}, figsize=(10, 6))
# Out:
# array([[<AxesSubplot:xlabel='.SPX', ylabel='.SPX'>,
#         <AxesSubplot:xlabel='.VIX', ylabel='.SPX'>],
#        [<AxesSubplot:xlabel='.SPX', ylabel='.VIX'>,
#         <AxesSubplot:xlabel='.VIX', ylabel='.VIX'>]], dtype=object)

# %%
data22 = pd.read_csv('data/tr_eikon_eod_data.csv', index_col=0, parse_dates=True)
data22 = data22[['.SPX', '.VIX']].dropna()
data22 = np.log(data22 / data22.shift(1)).dropna()

z1 = np.polyfit(data22['.SPX'], data22['.VIX'], 1)
f1 = np.poly1d(z1)

z2 = np.polyfit(data22['.SPX'], data22['.VIX'], 2)
f2 = np.poly1d(z2)

z3 = np.polyfit(data22['.SPX'], data22['.VIX'], 3)
f3 = np.poly1d(z3)

z6 = np.polyfit(data22['.SPX'], data22['.VIX'], 6)
f6 = np.poly1d(z6)

tmpX = np.linspace(data22['.SPX'].min(), data22['.SPX'].max(), 50)


ax = data22.plot(kind='scatter', x='.SPX', y='.VIX', figsize=(20, 12))
#ax = (data22['.SPX'],data22['.VIX'])
ax.scatter(tmpX, f1(tmpX),label='f1')
ax.scatter(tmpX, f2(tmpX),label='f1')
ax.scatter(tmpX, f3(tmpX),label='f2')
ax.scatter(tmpX, f6(tmpX),label='f6')
ax.legend(loc=2)

# %%
data23 = pd.read_csv('data/tr_eikon_eod_data.csv', index_col=0, parse_dates=True)
data23 = data23[['.SPX', '.VIX']].dropna()
data23 = np.log(data23 / data23.shift(1)).dropna()
data23.corr()
# Out:
#           .SPX      .VIX
# .SPX  1.000000 -0.804382
# .VIX -0.804382  1.000000

# %%
data24 = pd.read_csv('data/tr_eikon_eod_data.csv', index_col=0, parse_dates=True)
data24 = data24[['.SPX', '.VIX']].dropna()
data24 = np.log(data24 / data24.shift(1)).dropna()

ax = data24['.SPX'].rolling(window=252).corr(data24['.VIX']).plot(figsize=(15, 9))  
ax.axhline(data24.corr().iloc[0, 1], c='r')

# %%
# 可與data10比較 略有差異
data25 = pd.read_csv('data/tr_eikon_eod_data.csv', index_col=0, parse_dates=True)
(data25.pct_change()+1).cumprod().plot(figsize=(10, 6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
data26 = pd.read_csv('data/tr_eikon_eod_data.csv', index_col=0, parse_dates=True)
data26.pct_change().hist(bins=50, figsize=( 20,20))
# Out:
# array([[<AxesSubplot:title={'center':'AAPL.O'}>,
#         <AxesSubplot:title={'center':'MSFT.O'}>,
#         <AxesSubplot:title={'center':'INTC.O'}>],
#        [<AxesSubplot:title={'center':'AMZN.O'}>,
#         <AxesSubplot:title={'center':'GS.N'}>,
#         <AxesSubplot:title={'center':'SPY'}>],
#        [<AxesSubplot:title={'center':'.SPX'}>,
#         <AxesSubplot:title={'center':'.VIX'}>,
#         <AxesSubplot:title={'center':'EUR='}>],
#        [<AxesSubplot:title={'center':'XAU='}>,
#         <AxesSubplot:title={'center':'GDX'}>,
#         <AxesSubplot:title={'center':'GLD'}>]], dtype=object)

# %%
from pandas.plotting import scatter_matrix

data27 = pd.read_csv('data/tr_eikon_eod_data.csv', index_col=0, parse_dates=True)
# plot the scatter of daily price changed for ALL stocks
scatter_matrix(data27.pct_change(), diagonal='kde', figsize=(20,20))
# Out:
# array([[<AxesSubplot:xlabel='AAPL.O', ylabel='AAPL.O'>,
#         <AxesSubplot:xlabel='MSFT.O', ylabel='AAPL.O'>,
#         <AxesSubplot:xlabel='INTC.O', ylabel='AAPL.O'>,
#         <AxesSubplot:xlabel='AMZN.O', ylabel='AAPL.O'>,
#         <AxesSubplot:xlabel='GS.N', ylabel='AAPL.O'>,
#         <AxesSubplot:xlabel='SPY', ylabel='AAPL.O'>,
#         <AxesSubplot:xlabel='.SPX', ylabel='AAPL.O'>,
#         <AxesSubplot:xlabel='.VIX', ylabel='AAPL.O'>,
#         <AxesSubplot:xlabel='EUR=', ylabel='AAPL.O'>,
#         <AxesSubplot:xlabel='XAU=', ylabel='AAPL.O'>,
#         <AxesSubplot:xlabel='GDX', ylabel='AAPL.O'>,
#         <AxesSubplot:xlabel='GLD', ylabel='AAPL.O'>],
#        [<AxesSubplot:xlabel='AAPL.O', ylabel='MSFT.O'>,
#         <AxesSubplot:xlabel='MSFT.O', ylabel='MSFT.O'>,
#         <AxesSubplot:xlabel='INTC.O', ylabel='MSFT.O'>,
#         <AxesSubplot:xlabel='AMZN.O', ylabel='MSFT.O'>,
#         <AxesSubplot:xlabel='GS.N', ylabel='MSFT.O'>,
# ...

# %%
data28 = pd.read_csv('data/tr_eikon_eod_data.csv', index_col=0, parse_dates=True)
data28.pct_change().corr()
# Out:
#           AAPL.O    MSFT.O    INTC.O    AMZN.O      GS.N       SPY      .SPX  \
# AAPL.O  1.000000  0.410071  0.392106  0.345481  0.348797  0.563187  0.563700
# MSFT.O  0.410071  1.000000  0.564327  0.435314  0.447460  0.664952  0.667032
# INTC.O  0.392106  0.564327  1.000000  0.344512  0.442543  0.648278  0.649637
# AMZN.O  0.345481  0.435314  0.344512  1.000000  0.325177  0.528290  0.530371
# GS.N    0.348797  0.447460  0.442543  0.325177  1.000000  0.716525  0.717427
# SPY     0.563187  0.664952  0.648278  0.528290  0.716525  1.000000  0.996146
# .SPX    0.563700  0.667032  0.649637  0.530371  0.717427  0.996146  1.000000
# .VIX   -0.450570 -0.521633 -0.504262 -0.436655 -0.566053 -0.786053 -0.789301
# EUR=    0.083421  0.123082  0.150443  0.108166  0.172695  0.255915  0.258186
# XAU=    0.033571 -0.008381  0.000185 -0.026618 -0.059534  0.002689  0.006806
# GDX     0.149337  0.127061  0.135212  0.083201  0.080435  0.204684  0.207146
# ...

# %%
data29 = pd.read_csv('data/tr_eikon_eod_data.csv', index_col=0, parse_dates=True)
corrs = data29.pct_change().corr()

plt.imshow(corrs, cmap='hot', interpolation='none')
plt.colorbar()
plt.xticks(range(len(corrs)), corrs.columns)
plt.yticks(range(len(corrs)), corrs.columns)
plt.gcf().set_size_inches(20,20)

# %%
# Volatility
data30 = pd.read_csv('data/tr_eikon_eod_data.csv', index_col=0, parse_dates=True)
vol = data30.pct_change().rolling(window=100).std()
vol.plot(figsize=(20, 12))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# https://towardsdatascience.com/validate-your-pandas-dataframe-with-pandera-2995910e564

# %%
import pandas as pd

fruits = pd.DataFrame(
    {
        "name": ["apple", "banana", "apple", "orange"],
        "store": ["Aldi", "Walmart", "Walmart", "Aldi"],
        "price": [2, 1, 3, 4],
    }
)

fruits
# Out:
#      name    store  price
# 0   apple     Aldi      2
# 1  banana  Walmart      1
# 2   apple  Walmart      3
# 3  orange     Aldi      4

# %%
#pass validation

import pandera as pa
from pandera import Column, Check

available_fruits = ["apple", "banana", "orange"]
nearby_stores = ["Aldi", "Walmart"]

schema = pa.DataFrameSchema(
    {
        "name": Column(str, Check.isin(available_fruits)),
        "store": Column(str, Check.isin(nearby_stores)),
        "price": Column(int, Check.less_than(5)),
    }
)
schema.validate(fruits)
# Out:
#      name    store  price
# 0   apple     Aldi      2
# 1  banana  Walmart      1
# 2   apple  Walmart      3
# 3  orange     Aldi      4

# %%
#fail validation

import pandera as pa
from pandera import Column, Check

schema = pa.DataFrameSchema(
    {
        "name": Column(str, Check.isin(available_fruits)),
        "store": Column(str, Check.isin(nearby_stores)),
        "price": Column(int, Check.less_than(4)),
    }
)
schema.validate(fruits)
# not all price less than 4
# Out:
# ---------------------------------------------------------------------------
# SchemaError                               Traceback (most recent call last)
# /tmp/ipykernel_34511/888469391.py in <cell line: 13>()
#      11     }
#      12 )
# ---> 13 schema.validate(fruits)
#      14 # not all price less than 4
#
# ~/anaconda3/lib/python3.9/site-packages/pandera/schemas.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     591                 check_results.append(isinstance(result, pd.DataFrame))
#     592             except errors.SchemaError as err:
# --> 593                 error_handler.collect_error("schema_component_check", err)
#     594             except errors.SchemaErrors as err:
#     595                 for schema_error_dict in err.schema_errors:
#
# ~/anaconda3/lib/python3.9/site-packages/pandera/error_handlers.py in collect_error(self, reason_code, schema_error, original_exc)
#      30         """
#      31         if not self._lazy:
# ---> 32             raise schema_error from original_exc
#      33
#      34         # delete data of validated object from SchemaError object to prevent
#
# ~/anaconda3/lib/python3.9/site-packages/pandera/schemas.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     583         for schema_component in schema_components:
#     584             try:
# --> 585                 result = schema_component(
#     586                     df_to_validate,
#     587                     lazy=lazy,
#
# ~/anaconda3/lib/python3.9/site-packages/pandera/schemas.py in __call__(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#    1882     ) -> Union[pd.DataFrame, pd.Series]:
#    1883         """Alias for ``validate`` method."""
# -> 1884         return self.validate(
#    1885             check_obj, head, tail, sample, random_state, lazy, inplace
#    1886         )
#
# ~/anaconda3/lib/python3.9/site-packages/pandera/schema_components.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     199                     )
#     200             else:
# --> 201                 validate_column(check_obj, column_name)
#     202
#     203         return check_obj
#
# ~/anaconda3/lib/python3.9/site-packages/pandera/schema_components.py in validate_column(check_obj, column_name)
#     172
#     173         def validate_column(check_obj, column_name):
# --> 174             super(Column, copy(self).set_name(column_name)).validate(
#     175                 check_obj,
#     176                 head,
#
# ~/anaconda3/lib/python3.9/site-packages/pandera/schemas.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#    1844                 )
#    1845             except errors.SchemaError as err:
# -> 1846                 error_handler.collect_error("dataframe_check", err)
#    1847             except Exception as err:  # pylint: disable=broad-except
#    1848                 # catch other exceptions that may occur when executing the
#
# ~/anaconda3/lib/python3.9/site-packages/pandera/error_handlers.py in collect_error(self, reason_code, schema_error, original_exc)
#      30         """
#      31         if not self._lazy:
# ---> 32             raise schema_error from original_exc
#      33
#      34         # delete data of validated object from SchemaError object to prevent
#
# ~/anaconda3/lib/python3.9/site-packages/pandera/schemas.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#    1839             try:
#    1840                 check_results.append(
# -> 1841                     _handle_check_results(
#    1842                         self, check_index, check, check_obj, *check_args
#    1843                     )
#
# ~/anaconda3/lib/python3.9/site-packages/pandera/schemas.py in _handle_check_results(schema, check_index, check, check_obj, *check_args)
#    2154             warnings.warn(error_msg, UserWarning)
#    2155             return True
# -> 2156         raise errors.SchemaError(
#    2157             schema,
#    2158             check_obj,
#
# SchemaError: <Schema Column(name=price, type=<class 'int'>)> failed element-wise validator 0:
# <Check less_than: less_than(4)>
# failure cases:
#    index  failure_case
# 0      3             4

# %%
schema = pa.DataFrameSchema(
    {
        "name": Column(str, Check.isin(available_fruits)),
        "store": Column(str, Check.isin(nearby_stores)),
        "price": Column(
            int, [Check.less_than(5), Check(lambda price: sum(price) < 15)]
        ),
    }
)
schema.validate(fruits)
# Out:
#      name    store  price
# 0   apple     Aldi      2
# 1  banana  Walmart      1
# 2   apple  Walmart      3
# 3  orange     Aldi      4

# %%
# class

from pandera.typing import Series

class Schema(pa.SchemaModel):
    name: Series[str] = pa.Field(isin=available_fruits)
    store: Series[str] = pa.Field(isin=nearby_stores)
    price: Series[int] = pa.Field(le=5)

    @pa.check("price")
    def price_sum_lt_20(cls, price: Series[int]) -> Series[bool]:
        return sum(price) < 20

Schema.validate(fruits)
# Out:
#      name    store  price
# 0   apple     Aldi      2
# 1  banana  Walmart      1
# 2   apple  Walmart      3
# 3  orange     Aldi      4

# %%
fruits = pd.DataFrame(
    {
        "name": ["apple", "banana", "apple", "orange"],
        "store": ["Aldi", "Walmart", "Walmart", "Aldi"],
        "price": [2, 1, 3, 4],
    }
)

schema = pa.DataFrameSchema(
    {
        "name": Column(str, Check.isin(available_fruits)),
        "store": Column(str, Check.isin(nearby_stores)),
        "price": Column(int, Check.less_than(5)),
    }
)


def get_total_price(fruits: pd.DataFrame, schema: pa.DataFrameSchema):
    validated = schema.validate(fruits)
    return validated["price"].sum()

get_total_price(fruits, schema)
# Out:
# 10

# %%
#for unit test

def test_get_total_price():
    fruits = pd.DataFrame({'name': ['apple', 'banana'], 'store': ['Aldi', 'Walmart'], 'price': [1, 2]})
    
    # Need to include schema in the unit test
    schema = pa.DataFrameSchema(
        {
            "name": Column(str, Check.isin(available_fruits)),
            "store": Column(str, Check.isin(nearby_stores)),
            "price": Column(int, Check.less_than(5)),
        }
    )
    assert get_total_price(fruits, schema) == 3

test_get_total_price()

# %%
#decorator

from pandera import check_input

schema = pa.DataFrameSchema(
    {
        "name": Column(str, Check.isin(available_fruits)),
        "store": Column(str, Check.isin(nearby_stores)),
        "price": Column(int, Check.less_than(5)),
    })

@check_input(schema)
def get_total_price(fruits: pd.DataFrame):
    return fruits.price.sum()

get_total_price(fruits)
# Out:
# 10

# %%
# input check

fruits = pd.DataFrame(
    {
        "name": ["apple", "banana", "apple", "orange"],
        "store": ["Aldi", "Walmart", "Walmart", "Aldi"],
        "price": ["2", "1", "3", "4"],
        # "price": [2,1,3,4]
    }
)

@check_input(schema)
def get_total_price(fruits: pd.DataFrame):
    return fruits.price.sum()

get_total_price(fruits)
# Out:
# ---------------------------------------------------------------------------
# SchemaError                               Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/pandera/decorators.py in _wrapper(fn, instance, args, kwargs)
#     186             try:
# --> 187                 args[0] = schema.validate(args[0], *validate_args)
#     188             except errors.SchemaError as e:
#
# ~/anaconda3/lib/python3.9/site-packages/pandera/schemas.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     592             except errors.SchemaError as err:
# --> 593                 error_handler.collect_error("schema_component_check", err)
#     594             except errors.SchemaErrors as err:
#
# ~/anaconda3/lib/python3.9/site-packages/pandera/error_handlers.py in collect_error(self, reason_code, schema_error, original_exc)
#      31         if not self._lazy:
# ---> 32             raise schema_error from original_exc
#      33
#
# ~/anaconda3/lib/python3.9/site-packages/pandera/schemas.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     584             try:
# --> 585                 result = schema_component(
#     586                     df_to_validate,
#
# ~/anaconda3/lib/python3.9/site-packages/pandera/schemas.py in __call__(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#    1883         """Alias for ``validate`` method."""
# -> 1884         return self.validate(
#    1885             check_obj, head, tail, sample, random_state, lazy, inplace
#
# ~/anaconda3/lib/python3.9/site-packages/pandera/schema_components.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     200             else:
# --> 201                 validate_column(check_obj, column_name)
#     202
#
# ~/anaconda3/lib/python3.9/site-packages/pandera/schema_components.py in validate_column(check_obj, column_name)
#     173         def validate_column(check_obj, column_name):
# --> 174             super(Column, copy(self).set_name(column_name)).validate(
#     175                 check_obj,
#
# ~/anaconda3/lib/python3.9/site-packages/pandera/schemas.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#    1820             )
# -> 1821             error_handler.collect_error(
#    1822                 "wrong_pandas_dtype",
#
# ~/anaconda3/lib/python3.9/site-packages/pandera/error_handlers.py in collect_error(self, reason_code, schema_error, original_exc)
#      31         if not self._lazy:
# ---> 32             raise schema_error from original_exc
#      33
#
# SchemaError: expected series 'price' to have type 'int64', got 'object'
#
# During handling of the above exception, another exception occurred:
#
# SchemaError                               Traceback (most recent call last)
# /tmp/ipykernel_34511/406938186.py in <cell line: 16>()
#      14     return fruits.price.sum()
#      15
# ---> 16 get_total_price(fruits)
#
# ~/anaconda3/lib/python3.9/site-packages/pandera/decorators.py in _wrapper(fn, instance, args, kwargs)
#     187                 args[0] = schema.validate(args[0], *validate_args)
#     188             except errors.SchemaError as e:
# --> 189                 _handle_schema_error("check_input", fn, schema, args[0], e)
#     190         elif obj_getter is None and kwargs:
#     191             # get the first key in the same order specified in the
#
# ~/anaconda3/lib/python3.9/site-packages/pandera/decorators.py in _handle_schema_error(decorator_name, fn, schema, arg_df, schema_error)
#      62     """
#      63     msg = f"error in {decorator_name} decorator of function '{fn.__name__}': {schema_error}"
# ---> 64     raise errors.SchemaError(
#      65         schema,
#      66         arg_df,
#
# SchemaError: error in check_input decorator of function 'get_total_price': expected series 'price' to have type 'int64', got 'object'

# %%
# check_output

from pandera import check_output

fruits_nearby = pd.DataFrame(
    {
        "name": ["apple", "banana", "apple", "orange"],
        "store": ["Aldi", "Walmart", "Walmart", "Aldi"],
        "price": [2, 1, 3, 4],
    }
)

fruits_faraway = pd.DataFrame(
    {
        "name": ["apple", "banana", "apple", "orange"],
        "store": ["Whole Foods", "Whole Foods", "Schnucks", "Schnucks"],
        "price": [3, 2, 4, 5],
    }
)

out_schema = pa.DataFrameSchema(
    {"store": Column(str, Check.isin(["Aldi", "Walmart", "Whole Foods", "Schnucks"]))}
)


@check_output(out_schema)
def combine_fruits(fruits_nearby: pd.DataFrame, fruits_faraway: pd.DataFrame):
    fruits = pd.concat([fruits_nearby, fruits_faraway])
    return fruits


combine_fruits(fruits_nearby, fruits_faraway)
# Out:
#      name        store  price
# 0   apple         Aldi      2
# 1  banana      Walmart      1
# 2   apple      Walmart      3
# 3  orange         Aldi      4
# 0   apple  Whole Foods      3
# 1  banana  Whole Foods      2
# 2   apple     Schnucks      4
# 3  orange     Schnucks      5

# %%
# check input and output both

from pandera import check_io

in_schema = pa.DataFrameSchema({"store": Column(str)})

out_schema = pa.DataFrameSchema(
    {"store": Column(str, Check.isin(["Aldi", "Walmart", "Whole Foods", "Schnucks"]))}
)


@check_io(fruits_nearby=in_schema, fruits_faraway=in_schema, out=out_schema)
def combine_fruits(fruits_nearby: pd.DataFrame, fruits_faraway: pd.DataFrame):
    fruits = pd.concat([fruits_nearby, fruits_faraway])
    return fruits


combine_fruits(fruits_nearby, fruits_faraway)
# Out:
#      name        store  price
# 0   apple         Aldi      2
# 1  banana      Walmart      1
# 2   apple      Walmart      3
# 3  orange         Aldi      4
# 0   apple  Whole Foods      3
# 1  banana  Whole Foods      2
# 2   apple     Schnucks      4
# 3  orange     Schnucks      5

# %%
# nullable, default is not allowed

import numpy as np

fruits = fruits = pd.DataFrame(
    {
        "name": ["apple", "banana", "apple", "orange"],
        "store": ["Aldi", "Walmart", "Walmart", np.nan],
        "price": [2, 1, 3, 4],
    }
)

schema = pa.DataFrameSchema(
    {
        "name": Column(str, Check.isin(available_fruits)),
        "store": Column(str, Check.isin(nearby_stores), nullable=True),
        "price": Column(int, Check.less_than(5)),
    }
)
schema.validate(fruits)
# Out:
#      name    store  price
# 0   apple     Aldi      2
# 1  banana  Walmart      1
# 2   apple  Walmart      3
# 3  orange      NaN      4

# %%
# allow_duplicates

fruits = fruits = pd.DataFrame(
    {
        "name": ["apple", "banana", "apple", "orange"],
        "store": ["Aldi", "Walmart", "Walmart", np.nan],
        "price": [2, 1, 3, 4],
    }
)

schema = pa.DataFrameSchema(
    {
        "name": Column(str, Check.isin(available_fruits)),
        "store": Column(
            str, Check.isin(nearby_stores), nullable=True, allow_duplicates=False
        ),
        "price": Column(int, Check.less_than(5)),
    }
)
schema.validate(fruits)
# Out:
# ---------------------------------------------------------------------------
# SchemaError                               Traceback (most recent call last)
# /tmp/ipykernel_34511/2604884752.py in <cell line: 20>()
#      18     }
#      19 )
# ---> 20 schema.validate(fruits)
#
# ~/anaconda3/lib/python3.9/site-packages/pandera/schemas.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     591                 check_results.append(isinstance(result, pd.DataFrame))
#     592             except errors.SchemaError as err:
# --> 593                 error_handler.collect_error("schema_component_check", err)
#     594             except errors.SchemaErrors as err:
#     595                 for schema_error_dict in err.schema_errors:
#
# ~/anaconda3/lib/python3.9/site-packages/pandera/error_handlers.py in collect_error(self, reason_code, schema_error, original_exc)
#      30         """
#      31         if not self._lazy:
# ---> 32             raise schema_error from original_exc
#      33
#      34         # delete data of validated object from SchemaError object to prevent
#
# ~/anaconda3/lib/python3.9/site-packages/pandera/schemas.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     583         for schema_component in schema_components:
#     584             try:
# --> 585                 result = schema_component(
#     586                     df_to_validate,
#     587                     lazy=lazy,
#
# ~/anaconda3/lib/python3.9/site-packages/pandera/schemas.py in __call__(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#    1882     ) -> Union[pd.DataFrame, pd.Series]:
#    1883         """Alias for ``validate`` method."""
# -> 1884         return self.validate(
#    1885             check_obj, head, tail, sample, random_state, lazy, inplace
#    1886         )
#
# ~/anaconda3/lib/python3.9/site-packages/pandera/schema_components.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     199                     )
#     200             else:
# --> 201                 validate_column(check_obj, column_name)
#     202
#     203         return check_obj
#
# ~/anaconda3/lib/python3.9/site-packages/pandera/schema_components.py in validate_column(check_obj, column_name)
#     172
#     173         def validate_column(check_obj, column_name):
# --> 174             super(Column, copy(self).set_name(column_name)).validate(
#     175                 check_obj,
#     176                 head,
#
# ~/anaconda3/lib/python3.9/site-packages/pandera/schemas.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#    1795                     .to_dict(),
#    1796                 )
# -> 1797                 error_handler.collect_error(
#    1798                     "series_contains_duplicates",
#    1799                     errors.SchemaError(
#
# ~/anaconda3/lib/python3.9/site-packages/pandera/error_handlers.py in collect_error(self, reason_code, schema_error, original_exc)
#      30         """
#      31         if not self._lazy:
# ---> 32             raise schema_error from original_exc
#      33
#      34         # delete data of validated object from SchemaError object to prevent
#
# SchemaError: series 'store' contains duplicate values: {2: 'Walmart'}

# %%
# convert data type

fruits = pd.DataFrame(
    {
        "name": ["apple", "banana", "apple", "orange"],
        "store": ["Aldi", "Walmart", "Walmart", "Aldi"],
        "price": [2, 1, 3, 4],
    }
)

schema = pa.DataFrameSchema({"price": Column(str, coerce=True)})
validated = schema.validate(fruits)
validated.dtypes
# Out:
# name     object
# store    object
# price    object
# dtype: object

# %%
#regex pattern

favorite_stores = ["Aldi", "Walmart", "Whole Foods", "Schnucks"]

fruits = pd.DataFrame(
    {
        "name": ["apple", "banana", "apple", "orange"],
        "store_nearby": ["Aldi", "Walmart", "Walmart", "Aldi"],
        "store_far": ["Whole Foods", "Schnucks", "Whole Foods", "Schnucks"],
    }
)

schema = pa.DataFrameSchema(
    {
        "name": Column(str, Check.isin(available_fruits)),
        "store_+": Column(str, Check.isin(favorite_stores), regex=True),
    }
)
schema.validate(fruits)
# Out:
#      name store_nearby    store_far
# 0   apple         Aldi  Whole Foods
# 1  banana      Walmart     Schnucks
# 2   apple      Walmart  Whole Foods
# 3  orange         Aldi     Schnucks

# %%
# YAML
from pathlib import Path

# Get a YAML object
yaml_schema = schema.to_yaml()

# Save to a file
f = Path("data/schema.yml")
f.touch()
f.write_text(yaml_schema)
# Out:
# 528

# %%
with f.open() as file:
    yaml_schema = file.read()

schema = pa.io.from_yaml(yaml_schema)
schema
# Out:
# <Schema DataFrameSchema(columns={'name': <Schema Column(name=name, type=object)>, 'store_+': <Schema Column(name=store_+, type=object)>}, checks=[], index=None, coerce=False, pandas_dtype=None,strict=False,name=None,ordered=False)>
